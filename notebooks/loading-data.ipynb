# %% [markdown]
# 30699 AmazonWebServices.md
# 5574 Angular-web-framework.md
# 32704 C Sharp (programming language).md
# 20199 C++.md
# 52895 C-programming-language-.md
# 32704 C-Sharp-programming-language.md
# 31714 Go-programming-language.md
# 12891 GoogleCloudPlatform.md
# 26136 Java-programming-language.md
# 33447 JavaScript.md
# 26112 MicrosoftAzure.md
# 11440 MongoDB.md
# 23038 MySQL.md
# 38121 PostgreSQL.md
# 39363 Python-programming-language.md
# 17726 React-software.md
# 34936 Rust-programming-language.md
# 11214 Vue.js.md

# %%
print([30699,5574 ,32704,20199,52895,32704,31714,12891,26136,33447,26112,11440,23038,38121,39363,17726,34936,11214,])
# Out:
# None

# %%
from datasets import load_dataset

old = [492756726,
    493802927,
    490560885
]

dataset = load_dataset("text", data_files="../dataset/*.md", split="train")
print(dataset[0])
# Out:
# Resolving data files:   0%|          | 0/21 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# {'text': '# Amazon Web Services'}

# %%
print(len(dataset))
print(dataset[0])
# Out:
# 3671
# {'text': '# Amazon Web Services'}

# %%
dataset_l = list(dataset.iter( batch_size=len(dataset)))
dataset_l[:5]
data = dataset_l[0].get("text",  [])
print(data[:1000])
# Out:
# ['# Amazon Web Services', '', '## Summary', '', 'Amazon Web Services, Inc. (AWS) is a subsidiary of Amazon that provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered, pay-as-you-go basis.', 'Clients often use this in combination with autoscaling (a process that allows a client to use more computing in times of high application usage, and then scale down to reduce costs when there is less traffic). These cloud computing web services provide various services related to networking, compute, storage, middleware, IoT and other processing capacity, as well as software tools via AWS server farms.  This frees clients from managing, scaling, and patching hardware and operating systems.', "One of the foundational services is Amazon Elastic Compute Cloud (EC2), which allows users to have at their disposal a virtual cluster of computers, with extremely high availability, which can be interacted with over the internet via REST APIs, a CLI o
# ...

# %%
with open("../data/all_cleaned_text.md", "w", encoding="utf-8") as f:
    f.write("\n".join(data))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[41], line 3
#       1 with open("../data/all_cleaned_text.md", "w", encoding="utf-8") as f:
#       2     f.write("\n".join(data))
# ----> 3     content= f.read()
#
# UnsupportedOperation: not readable

# %%
with open("../data/all_cleaned_text.md", "r", encoding="utf-8") as f:
    content = f.read()

# %%
len(content)
# Out:
# 547096

# %%
all_tokens = []
for item in dataset:
    # split and also add \n to the tokens, so we can keep track of line breaks
    tokens = item["text"].split() + ["\n"]
    all_tokens.extend(tokens)
print(f"Total number of tokens: {len(all_tokens)}")
# Out:
# Total number of tokens: 87954

# %%
all_tokens[:100]
# Out:
# ['#',
#  'Amazon',
#  'Web',
#  'Services',
#  '\n',
#  '\n',
#  '##',
#  'Summary',
#  '\n',
#  '\n',
#  'Amazon',
#  'Web',
#  'Services,',
#  'Inc.',
#  '(AWS)',
#  'is',
#  'a',
#  'subsidiary',
#  'of',
#  'Amazon',
#  'that',
#  'provides',
#  'on-demand',
#  'cloud',
#  'computing',
#  'platforms',
#  'and',
#  'APIs',
#  'to',
#  'individuals,',
#  'companies,',
#  'and',
#  'governments,',
#  'on',
#  'a',
#  'metered,',
#  'pay-as-you-go',
#  'basis.',
#  '\n',
#  'Clients',
#  'often',
#  'use',
#  'this',
#  'in',
#  'combination',
#  'with',
#  'autoscaling',
#  '(a',
#  'process',
#  'that',
#  'allows',
#  'a',
#  'client',
#  'to',
#  'use',
#  'more',
#  'computing',
#  'in',
#  'times',
#  'of',
#  'high',
#  'application',
#  'usage,',
#  'and',
#  'then',
#  'scale',
#  'down',
#  'to',
#  'reduce',
#  'costs',
#  'when',
#  'there',
#  'is',
#  'less',
#  'traffic).',
#  'These',
#  'cloud',
#  'computing',
#  'web',
#  'services',
#  'provide',
#  'various',
# ...

# %%
all_text_31 = " ".join(ds31["train"]["text"]) 
all_text_32 = " ".join(ds32["train"]["text"]) 
all_text_33 = " ".join(ds33["train"]["text"]) 

print(len(all_text_31))
print(len(all_text_32))
print(len(all_text_33))
# Out:
# 492756726
# 493802927
# 490560885

# %%
print(len(all_text_31))
print(len(all_text_32))
print(len(all_text_33[len(all_text_33)//2:3*len(all_text_33)//4]))
# Out:
# 492756726
# 493802927
# 122640221

# %%
all_text = all_text_31 + " " + all_text_32 + " " + all_text_33[len(all_text_33)//2:3*len(all_text_33)//4]

# %%
len(all_text)
# Out:
# 1109199876

# %%
with open("../data/train-31-32-33-of-00080.txt", "w", encoding="utf-8") as f:
    f.write(all_text)
    f.flush() # Ensure data is written to disk
    f.close()

# %%
with open("../data/train-31-32-33-of-00080.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print(len(content))
# Out:
# 1109199876

# %%
from datasets import load_dataset

ds = load_dataset("rojagtap/bookcorpus")
# Out:
# README.md:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\datasets--rojagtap--bookcorpus. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
ds["train"].to_json("../data/bookcorpus_train.jsonl")
# Out:
# Creating json from Arrow format:   0%|          | 0/74005 [00:00<?, ?ba/s]
# 5427456639

# %%
txt = ' '.join(ds["train"]["text"][:1000000])

# %%
path_ = "../data/bookcorpus.txt"

with open(path_, "r") as f:
    # f.write(txt)
    content = f.read()

# %%
content[:200]
# Out:
# 'the half-ling book one in the fall of igneeria series kaylee soderburg copyright 2013 kaylee soderburg all rights reserved . isbn : 1492913731 isbn-13 : 978-1492913733 for my family , who encouraged m'

# %%
from datasets import load_dataset
import pandas as pd

# Load Alpaca dataset
ds = load_dataset("tatsu-lab/alpaca")

# Convert train split to pandas DataFrame
df = ds["train"].to_pandas()

# Save as CSV
df.to_csv("alpaca.csv", index=False, encoding="utf-8")

print(f"Saved {len(df)} rows to alpaca.csv")
# Out:
# Saved 52002 rows to alpaca.csv
