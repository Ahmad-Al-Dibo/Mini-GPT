# %%
import torch
import os
import sys

project_root = os.path.abspath("..")
sys.path.insert(0, project_root)

from gpt_lib import Config

# %%
checkpoint = torch.load("../output/mini_gpt.pth", map_location=torch.device("cpu"))

# %%
checkpoint_config = checkpoint.get("config", {})

# %%
checkpoint_config
# Out:
# {'config': {'embed_dim': 64,
#   'block_size': 32,
#   'batch_size': 32,
#   'epochs': 10,
#   'learning_rate': 0.00025,
#   'weight_decay': 0.1,
#   'dropout': 0.1,
#   'grad_clip': 1.0,
#   'num_blocks': 1,
#   'model_path': 'output/test.pth',
#   'data_path': 'data/data.txt',
#   'domain_data_path': None,
#   'domain_data_repeats': 1,
#   'tokenizer_type': 'sentencepiece',
#   'sentencepiece_model_type': 'bpe',
#   'sentencepiece_character_coverage': 1.0,
#   'tokenizer_max_line_length': 4000,
#   'tokenizer_rare_threshold': 2,
#   'max_vocab': 10000,
#   'max_data_size': 1000000,
#   'device': 'cpu',
#   'validation_split': 0.1,
#   'early_stopping_patience': 2,
#   'early_stopping_min_delta': 0.0001,
#   'restore_best_model': True,
#   'seed': 42,
#   'training_log_interval': 50,
#   'diagnostic_top_k': 5,
#   'concept_benchmark_top_k': 10,
#   'diagnostic_prompts': ['machine learning', 'donald trump siad'],
#   'diagnostic_sample_tokens': 60,
# ...

# %%
alls_config = Config().to_dict()

# %%
all_keys = alls_config["config"].keys()

# %%
checkpoint_keys = checkpoint_config.keys()
checkpoint_keys
# Out:
# dict_keys(['embed_dim', 'block_size', 'batch_size', 'epochs', 'learning_rate', 'weight_decay', 'dropout', 'grad_clip', 'num_blocks', 'model_path', 'data_path', 'domain_data_path', 'domain_data_repeats', 'tokenizer_type', 'sentencepiece_model_type', 'sentencepiece_character_coverage', 'max_vocab', 'max_data_size', 'device', 'validation_split', 'early_stopping_patience', 'early_stopping_min_delta', 'restore_best_model', 'seed', 'diagnostic_top_k', 'concept_benchmark_top_k', 'diagnostic_prompts', 'diagnostic_sample_tokens', 'tokenizer_rare_threshold', 'training_log_interval', 'run_long_context_evaluation', 'long_context_block_sizes'])

# %%
for key in checkpoint_keys:
    if key not in all_keys:
        print(f"{key}: NOT-FOUND!")
    else:
        print(f"{key}: FOUND!")
# Out:
# embed_dim: FOUND!
# block_size: FOUND!
# batch_size: FOUND!
# epochs: FOUND!
# learning_rate: FOUND!
# weight_decay: FOUND!
# dropout: FOUND!
# grad_clip: FOUND!
# num_blocks: FOUND!
# model_path: FOUND!
# data_path: FOUND!
# domain_data_path: FOUND!
# domain_data_repeats: FOUND!
# tokenizer_type: FOUND!
# sentencepiece_model_type: FOUND!
# sentencepiece_character_coverage: FOUND!
# max_vocab: FOUND!
# max_data_size: FOUND!
# device: FOUND!
# validation_split: FOUND!
# early_stopping_patience: FOUND!
# early_stopping_min_delta: FOUND!
# restore_best_model: FOUND!
# seed: FOUND!
# diagnostic_top_k: FOUND!
# concept_benchmark_top_k: FOUND!
# diagnostic_prompts: FOUND!
# diagnostic_sample_tokens: FOUND!
# tokenizer_rare_threshold: FOUND!
# training_log_interval: FOUND!
# run_long_context_evaluation: FOUND!
# long_context_block_sizes: FOUND!

# %%
checkpoint_config.get("device")
# Out:
# 'cuda'
