# %%
import random
import re

# %%
tokens = """

## Summary

Amazon Web Services, Inc. (AWS) is a subsidiary of Amazon that provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered, pay-as-you-go basis.a
Clients often use! this in combination with autoscaling (a process that allows a client to use more computing in times of high application usage, and then scale down to reduce costs when there is less traffic). These cloud computing web services provide various services related to networking, compute, storage, middleware, IoT and other processing capacity, as well as software tools via AWS server farms.  This frees clients from managing, scaling, and patching hardware and operating systems.

"""

# %%
text = " ".join(tokens)
sentences = [
        sentence.strip()
        for sentence in re.findall(r"[^.!?\n]+[.!?]?", text)
        if sentence.strip()
    ]

# %%
fake_data = [
    "## Summary",
    "Amazon Web Services, Inc."
]

# %%
rq = random.Random(42)
rq.shuffle(sentences)

# %%
sentences
# Out:
# ['A m a z o n   W e b   S e r v i c e s ,   I n c .',
#  'T h e s e   c l o u d   c o m p u t i n g   w e b   s e r v i c e s   p r o v i d e   v a r i o u s   s e r v i c e s   r e l a t e d   t o   n e t w o r k i n g ,   c o m p u t e ,   s t o r a g e ,   m i d d l e w a r e ,   I o T   a n d   o t h e r   p r o c e s s i n g   c a p a c i t y ,   a s   w e l l   a s   s o f t w a r e   t o o l s   v i a   A W S   s e r v e r   f a r m s .',
#  'a',
#  'C l i e n t s   o f t e n   u s e !',
#  '# #   S u m m a r y',
#  't h i s   i n   c o m b i n a t i o n   w i t h   a u t o s c a l i n g   ( a   p r o c e s s   t h a t   a l l o w s   a   c l i e n t   t o   u s e   m o r e   c o m p u t i n g   i n   t i m e s   o f   h i g h   a p p l i c a t i o n   u s a g e ,   a n d   t h e n   s c a l e   d o w n   t o   r e d u c e   c o s t s   w h e n   t h e r e   i s   l e s s   t r a f f i c ) .',
#  'T h i s   f r e e s   c l i e n t s   f r o m   m a n a g i n g ,   s c a l i n g ,   a n d   p a t c h i n g   h a r d w a r e   a n d   o p e r a t i n g   s y s t e m s .',
#  '( A W S )   i s   a   s u b s i d i a r y   o f   A m a z o n   t h a t   p r o v i d e s   o n - d e m a n d   c l o u d   c o m p u t i n g   p l a t f o r m s   a n d   A P I s   t o   i n d i v i d u a l s ,   c o m p a n i e s ,   a n d   g o v e r n m e n t s ,   o n   a   m e t e r e d ,   p a y - a s - y o u - g o   b a s i s .']

# %%
val_sentence_count = max(1, int(len(sentences) * 0.2))
val_sentence_count
# Out:
# 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(va)
#
# NameError: name 'va' is not defined
